# %%
import pandas as pd

# %%
import numpy as np

# %%
IMDB = pd.read_csv("../Data/IMDb_Data_final.csv")

# %%
IMDB
# Out:
#                                  Title             Director  \
# 0                    Top Gun: Maverick       JosephKosinski
# 1    Everything Everywhere All at Once             DanKwan,
# 2                           The Batman           MattReeves
# 3                        Jurassic Park      StevenSpielberg
# 4                        The Godfather   FrancisFordCoppola
# ..                                 ...                  ...
# 995                          Vizontele       YilmazErdogan,
# 996                          Sarfarosh    JohnMathewMatthan
# 997                              Udaan  VikramadityaMotwane
# 998                   English Vinglish          GauriShinde
# 999                              Anand  HrishikeshMukherjee
#
#                                                  Stars  IMDb-Rating  \
# 0    TomCruise, JenniferConnelly, MilesTeller, ValK...          8.6
# 1    , MichelleYeoh, StephanieHsu, KeHuyQuan, James...          8.3
# ...

# %%
IMDB1 = IMDB[['Title', 'IMDb-Rating','Category','ReleaseYear']]

# %%
IMDB1
# Out:
#                                  Title  IMDb-Rating                 Category  \
# 0                    Top Gun: Maverick          8.6             Action,Drama
# 1    Everything Everywhere All at Once          8.3  Action,Adventure,Comedy
# 2                           The Batman          7.9       Action,Crime,Drama
# 3                        Jurassic Park          8.2  Action,Adventure,Sci-Fi
# 4                        The Godfather          9.2              Crime,Drama
# ..                                 ...          ...                      ...
# 995                          Vizontele          8.0             Comedy,Drama
# 996                          Sarfarosh          8.1    Action,Drama,Thriller
# 997                              Udaan          8.1                    Drama
# 998                   English Vinglish          7.8      Comedy,Drama,Family
# 999                              Anand          8.1            Drama,Musical
#
#      ReleaseYear
# 0           2022
# ...

# %%
IMDB2 = IMDB1.drop(IMDB1[IMDB1.ReleaseYear < 2018].index)

# %%
IMDB2.head()
# Out:
#                                Title  IMDb-Rating                  Category  \
# 0                  Top Gun: Maverick          8.6              Action,Drama
# 1  Everything Everywhere All at Once          8.3   Action,Adventure,Comedy
# 2                         The Batman          7.9        Action,Crime,Drama
# 5            Spider-Man: No Way Home          8.3  Action,Adventure,Fantasy
# 6             RRR (Rise Roar Revolt)          8.1              Action,Drama
#
#    ReleaseYear
# 0         2022
# 1         2022
# 2         2022
# 5         2021
# 6         2022

# %%
IMDB2
# Out:
#                                  Title  IMDb-Rating                  Category  \
# 0                    Top Gun: Maverick          8.6              Action,Drama
# 1    Everything Everywhere All at Once          8.3   Action,Adventure,Comedy
# 2                           The Batman          7.9        Action,Crime,Drama
# 5              Spider-Man: No Way Home          8.3  Action,Adventure,Fantasy
# 6               RRR (Rise Roar Revolt)          8.1              Action,Drama
# ..                                 ...          ...                       ...
# 904                             Padman          7.9    Biography,Comedy,Drama
# 905           Uri: The Surgical Strike          8.2      Action,Drama,History
# 906                         Chhichhore          8.2      Comedy,Drama,Romance
# 917                         Badhaai ho          8.0              Comedy,Drama
# 962                         Drishyam 2          8.4      Crime,Drama,Thriller
#
#      ReleaseYear
# ...

# %%
IMDB3 = IMDB2.sort_values("ReleaseYear")

# %%
pd.set_option('display.max_rows', 1000)

# %%
IMDB3
# Out:
#                                   Title  IMDb-Rating  \
# 29        Mission: Impossible - Fallout          7.7
# 146                    K.G.F: Chapter 1          8.2
# 102   Spider-Man: Into the Spider-Verse          8.4
# 101                          Deadpool 2          7.7
# 254                      A Star Is Born          7.6
# 748                            Ratsasan          8.3
# 63                    Bohemian Rhapsody          7.9
# 917                          Badhaai ho          8.0
# 54               Avengers: Infinity War          8.4
# 359                       Incredibles 2          7.6
# 211                          Green Book          8.2
# 403                          Capharnaüm          8.4
# 695            Doragon bôru chô: Burorî          7.8
# 537                        Isle of Dogs          7.8
# 742                           Andhadhun          8.2
# 574                           Searching          7.6
# 585                                Roma          7.7
# ...
